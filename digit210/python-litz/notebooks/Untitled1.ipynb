# %%
# !pip install "numpy<2.0"
# !pip install torch transformers
# !pip install --upgrade torch 
# !pip install ipywidgets
# Out:
# Requirement already satisfied: numpy<2.0 in /Users/meganlitz28/Desktop/github/digit110/digit210/python-litz/.venv/lib/python3.14/site-packages (1.26.4)
# ERROR: Could not find a version that satisfies the requirement torch (from versions: none)
# ERROR: No matching distribution found for torch
# ERROR: Could not find a version that satisfies the requirement torch (from versions: none)
# ERROR: No matching distribution found for torch
# Requirement already satisfied: ipywidgets in /Users/meganlitz28/Desktop/github/digit110/digit210/python-litz/.venv/lib/python3.14/site-packages (8.1.8)
# Requirement already satisfied: comm>=0.1.3 in /Users/meganlitz28/Desktop/github/digit110/digit210/python-litz/.venv/lib/python3.14/site-packages (from ipywidgets) (0.2.3)
# Requirement already satisfied: ipython>=6.1.0 in /Users/meganlitz28/Desktop/github/digit110/digit210/python-litz/.venv/lib/python3.14/site-packages (from ipywidgets) (9.11.0)
# Requirement already satisfied: traitlets>=4.3.1 in /Users/meganlitz28/Desktop/github/digit110/digit210/python-litz/.venv/lib/python3.14/site-packages (from ipywidgets) (5.14.3)
# Requirement already satisfied: widgetsnbextension~=4.0.14 in /Users/meganlitz28/Desktop/github/digit110/digit210/python-litz/.venv/lib/python3.14/site-packages (from ipywidgets) (4.0.15)
# Requirement already satisfied: jupyterlab_widgets~=3.0.15 in /Users/meganlitz28/Desktop/github/digit110/digit210/python-litz/.venv/lib/python3.14/site-packages (from ipywidgets) (3.0.16)
# Requirement already satisfied: decorator>=5.1.0 in /Users/meganlitz28/Desktop/github/digit110/digit210/python-litz/.venv/lib/python3.14/site-packages (from ipython>=6.1.0->ipywidgets) (5.2.1)
# Requirement already satisfied: ipython-pygments-lexers>=1.0.0 in /Users/meganlitz28/Desktop/github/digit110/digit210/python-litz/.venv/lib/python3.14/site-packages (from ipython>=6.1.0->ipywidgets) (1.1.1)
# Requirement already satisfied: jedi>=0.18.2 in /Users/meganlitz28/Desktop/github/digit110/digit210/python-litz/.venv/lib/python3.14/site-packages (from ipython>=6.1.0->ipywidgets) (0.19.2)
# Requirement already satisfied: matplotlib-inline>=0.1.6 in /Users/meganlitz28/Desktop/github/digit110/digit210/python-litz/.venv/lib/python3.14/site-packages (from ipython>=6.1.0->ipywidgets) (0.2.1)
# Requirement already satisfied: pexpect>4.6 in /Users/meganlitz28/Desktop/github/digit110/digit210/python-litz/.venv/lib/python3.14/site-packages (from ipython>=6.1.0->ipywidgets) (4.9.0)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in /Users/meganlitz28/Desktop/github/digit110/digit210/python-litz/.venv/lib/python3.14/site-packages (from ipython>=6.1.0->ipywidgets) (3.0.52)
# Requirement already satisfied: pygments>=2.14.0 in /Users/meganlitz28/Desktop/github/digit110/digit210/python-litz/.venv/lib/python3.14/site-packages (from ipython>=6.1.0->ipywidgets) (2.19.2)
# Requirement already satisfied: stack_data>=0.6.0 in /Users/meganlitz28/Desktop/github/digit110/digit210/python-litz/.venv/lib/python3.14/site-packages (from ipython>=6.1.0->ipywidgets) (0.6.3)
# Requirement already satisfied: wcwidth in /Users/meganlitz28/Desktop/github/digit110/digit210/python-litz/.venv/lib/python3.14/site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython>=6.1.0->ipywidgets) (0.6.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /Users/meganlitz28/Desktop/github/digit110/digit210/python-litz/.venv/lib/python3.14/site-packages (from jedi>=0.18.2->ipython>=6.1.0->ipywidgets) (0.8.6)
# Requirement already satisfied: ptyprocess>=0.5 in /Users/meganlitz28/Desktop/github/digit110/digit210/python-litz/.venv/lib/python3.14/site-packages (from pexpect>4.6->ipython>=6.1.0->ipywidgets) (0.7.0)
# Requirement already satisfied: executing>=1.2.0 in /Users/meganlitz28/Desktop/github/digit110/digit210/python-litz/.venv/lib/python3.14/site-packages (from stack_data>=0.6.0->ipython>=6.1.0->ipywidgets) (2.2.1)
# Requirement already satisfied: asttokens>=2.1.0 in /Users/meganlitz28/Desktop/github/digit110/digit210/python-litz/.venv/lib/python3.14/site-packages (from stack_data>=0.6.0->ipython>=6.1.0->ipywidgets) (3.0.1)
# Requirement already satisfied: pure-eval in /Users/meganlitz28/Desktop/github/digit110/digit210/python-litz/.venv/lib/python3.14/site-packages (from stack_data>=0.6.0->ipython>=6.1.0->ipywidgets) (0.2.3)

# %%
# %pip install torch torchvision torchaudio transformers
# Out:
# ERROR: Could not find a version that satisfies the requirement torch (from versions: none)
# ERROR: No matching distribution found for torch
# Note: you may need to restart the kernel to use updated packages.

# %%
import sys
# !{sys.executable} -m pip install torch torchvision torchaudio transformers
# Out:
# ERROR: Could not find a version that satisfies the requirement torch (from versions: none)
# ERROR: No matching distribution found for torch

# %%
import sys
print(sys.executable)
# Out:
# /Users/meganlitz28/Desktop/github/digit110/digit210/python-litz/.venv/bin/python3.14

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl
from matplotlib import gridspec

# pytorch libraries
import torch
import torch.nn.functional as F
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[9], line 7
#       4 from matplotlib import gridspec
#       6 # pytorch libraries
# ----> 7 import torch
#       8 import torch.nn.functional as F
#
# ModuleNotFoundError: No module named 'torch'

# %%
tokenizer.vocab_size
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 tokenizer.vocab_size
#
# NameError: name 'tokenizer' is not defined

# %%
from transformers import (
    GPT2Tokenizer,
    BertTokenizer,
    RobertaTokenizer,
    T5Tokenizer,
    AutoTokenizer,
)

# Load tokenizers (downloads on first run, cached after)
tokenizers = {
    "GPT-2  (BPE)":         GPT2Tokenizer.from_pretrained("gpt2"),
    "BERT   (WordPiece)":   BertTokenizer.from_pretrained("bert-base-uncased"),
    "RoBERTa(BPE)":         RobertaTokenizer.from_pretrained("roberta-base"),
    "T5     (SentencePiece)":T5Tokenizer.from_pretrained("t5-small"),
    "Auto   → DistilBERT":  AutoTokenizer.from_pretrained("distilbert-base-uncased"),
}

# %%
for t in np.random.randint(tokenizer.vocab_size,size=10):
  print(f'Token {t:>5} is "{tokenizer.decode([t])}"')

# %%
print(tokenizer.encode('th'))
print(tokenizer.encode('tq'))

# %%
txt = 'I like the longer-form posts on Substack.'

tokens = tokenizer.encode(txt)
print(f'The sentence contains {len(txt)} characters and {len(tokens)} tokens.\n')

print('  Index  |  Token')
print('---------+-----------')
for t in tokens:
  print(f'  {t:>5}  |  "{tokenizer.decode([t])}"')
