# %% [markdown]
# # Messing with Jupyter Notebook in class

# %%
import nltk
nltk.download('book')

# %% [markdown]
# from nltk.book import *
# from urllib import request

# %% [markdown]
# import matplotlib
# import matplotlib.pyplot as plt

# %%
import tk

# %%
plt.plot(range(10))
plt.show()
![Figure_1.png](attachment:8a2e8b06-9844-4db7-b29c-2d47f1d80a76.png)

# %% [markdown]
# text6.dispersion_plot(['rabbit', 'grail', 'coconut', 'arthur', 'king', 'camelot'])
# plt.show()
# ![Figure_2.png](attachment:dd80db4b-6deb-493a-b3c2-b3e4820c2ab7.png)

# %%
print(len(set(text6)))

# %%
text1.concordance("monstrous")
text1.similar("monstrous")
text2.similar("monstrous")
text2.common_contexts(["monstrous", "very"])

# %% [markdown]
# text4.dispersion_plot(["citizens", "democracy", "freedom", "duties", "America"])
# plt.show()
# ![Figure_3.png](attachment:2cb14d3c-8530-4536-ad88-3ca1c9570f12.png)

# %%
text3.generate()
